# %%
from retrieval.retriever import Retriever
from generation import *

# %%
retriever = Retriever()
query = "What is the main topic of the document?"
results = retriever.retrieve_chunks(query, top_k=5)
print("Retrieved Chunks:")
for i, chunk in enumerate(results):
    print(f"Chunk {i+1}:")
    print(f"Source: {chunk.source}")
    print(f"Page: {chunk.metadata.get('page_number')}")
    print(f"Content: {chunk.text}\n")
    print(f"Score: {chunk.score}\n")

# %%
import sys
print(sys.executable)

# %%
from generation.prompt import build_prompt_template

# %%
print( build_prompt_template())

# %%
from generation.chain import answer_question

# %%
from graph.graph import run_agent
print(run_agent("how can lung cancer be detected?"))
# Out:
# ...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# d:\project\Groundwork\agent\.venv\Lib\site-packages\pydantic\main.py:250: UserWarning: WARNING! retries is not default parameter.
#                     retries was transferred to model_kwargs.
#                     Please confirm that retries is what you intended.
#   validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
# ...

# %%
from config import configs
print(repr(configs.or_api_key))  # '' means .env never loaded
import os
print(os.getcwd())               # where it looks for .env
# Out:
# '<REDACTED_OPENROUTER_KEY>'
# d:\project\Groundwork\agent\src
